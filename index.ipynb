# %% [markdown]
# # Querying with SQLAlchemy - Lab
#
# ## Introduction
#
# In this lesson, we'll learn how to use SQLAlchemy to write queries about Microsoft's _Northwind Traders_ database!
#
# ## Objectives
#
# You will be able to:
#
# * Read and understand an ERD diagram
# * Create queries with SQLAlchemy, including queries that involve many-to-many relationships
#
# ## Getting Started
#
# In order to complete this lab, we'll need to download a SQLite3-compatible version of the _Northwind Traders_ database from Microsoft.  Microsoft built this database back in the year 2000 to help showcase their SQL Server technology. Since then, it has been open-sourced and has become a great practice tool for every new generation of SQL learners.
#
# Lucky for us, some generous programmers have already converted the Northwind database to a sqlite-compatible version and posted it on Github. We've already included the file the SQL database file that we'll be working with in the repo for this folder, along with the following ERD Diagram. However, if you would like to work with the larger version of this dataset at a future time, just clone [this repo](https://github.com/jpwhite3/northwind-SQLite3) and follow their instructions to access it!
#
# ## ERD Diagram For Northwind Traders
#
# The following ERD Diagram describes the Northwind Traders Database:
#
# <img src='Northwind_ERD.png'>
#
# If the text seems a bit hard to read inside this jupyter notebook, just go into the folder for this repo and open the `Northwind_ERD.png` file manually to see it full size.
#
# ## Connecting to the Database
#
# The first thing we'll need to do is connect to the Northwind Traders database, which can be found in the file `Northwind_small.sqlite`.
#
# In the cell below, import the necessary tools from the `sqlalchemy` library, and take the necessary steps to connect to the database.
#
# **_NOTE:_** We won't be modifying the information in the database at all, just querying it, so there's no need to import the various things you would need to create declarative base classes and the like.

# %%
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy.orm import Session, sessionmaker
from sqlalchemy import *

engine = create_engine('sqlite:///Northwind_small.sqlite', echo=True)
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ## Get Table Names and Table Information
#
# One of the most useful things we can do when working with a new database is to inspect the tables until we have a solid idea of what we're looking at.  As you work through this lab, you'll notice that there are some small discrepancies between the Table/Column names listed in the ERD and what they are actually are in the database.  This may be annoying, but this is not an accident--sometimes, documentation is wrong!  By learning how to inspect what tables exist in a database, as well as how which columns exist inside a table, we can save ourselves a lot of headaches by double checking.
#
# In the cell below:
#
# * Import `inspect` from sqlalchemy
# * Create an inspector object by passing in `engine` to `inspect`
# * Use the appropriate inspector function to get the names of all tables

# %%
from sqlalchemy import inspect

inspector = inspect(engine)

print(inspector.get_table_names())
# Out:
# 2019-01-19 22:23:39,123 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-01-19 22:23:39,124 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 22:23:39,125 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-01-19 22:23:39,126 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 22:23:39,128 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-01-19 22:23:39,129 INFO sqlalchemy.engine.base.Engine ()
# ['Category', 'Customer', 'CustomerCustomerDemo', 'CustomerDemographic', 'Employee', 'EmployeeTerritory', 'Order', 'OrderDetail', 'Product', 'Region', 'Shipper', 'Supplier', 'Territory']

# %% [markdown]
# Great! We can now see exactly what each Table is named.
#
# **_Question_**:
#
# Are there any discrepancies between the table names and the ERD diagrams? if so, what are they?
#
# Write your answer below this line:
# ________________________________________________________________________________________________________________________________
# ERD lists tables as plurals, where the server table names are singular (with the exception of `Region`).
#
#
# Let's inspect the column names on one of the tables as well. In the cell below, call the appropriate method to get all column names for the `'Employee'` table.

# %%
print(inspector.get_columns('Employee'))
# Out:
# 2019-01-19 22:27:46,747 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Employee")
# 2019-01-19 22:27:46,748 INFO sqlalchemy.engine.base.Engine ()
# [{'name': 'Id', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 1}, {'name': 'LastName', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'FirstName', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Title', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'TitleOfCourtesy', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'BirthDate', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'HireDate', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Address', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'City', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Region', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'PostalCode', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Country', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'HomePhone', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Extension', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Photo', 'type': BLOB(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'Notes', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'ReportsTo', 'type': INTEGER(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}, {'name': 'PhotoPath', 'type': VARCHAR(length=8000), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}]

# %% [markdown]
# That output is good, but its a bit messy. Let's write a function that makes it a bit more readable, and only tells us what we need to know.
#
# The current structure of the output is a list of dictionaries. Complete the function below so that when the function is called and passed a table name, it prints out the name and type of each column in a well-formatted way.

# %%
def get_columns_info(col_name):
    cols_list = inspector.get_columns(col_name)
    
    print("Table Name: {}".format(col_name))
    print("")
    
    for column in cols_list:
        print("Name: {} \t Type: {}".format(column['name'], column['type']))

get_columns_info('Employee')
# Out:
# Table Name: Employee
#
# Name: Id 	 Type: INTEGER
# Name: LastName 	 Type: VARCHAR(8000)
# Name: FirstName 	 Type: VARCHAR(8000)
# Name: Title 	 Type: VARCHAR(8000)
# Name: TitleOfCourtesy 	 Type: VARCHAR(8000)
# Name: BirthDate 	 Type: VARCHAR(8000)
# Name: HireDate 	 Type: VARCHAR(8000)
# Name: Address 	 Type: VARCHAR(8000)
# Name: City 	 Type: VARCHAR(8000)
# Name: Region 	 Type: VARCHAR(8000)
# Name: PostalCode 	 Type: VARCHAR(8000)
# Name: Country 	 Type: VARCHAR(8000)
# Name: HomePhone 	 Type: VARCHAR(8000)
# Name: Extension 	 Type: VARCHAR(8000)
# Name: Photo 	 Type: BLOB
# Name: Notes 	 Type: VARCHAR(8000)
# Name: ReportsTo 	 Type: INTEGER
# Name: PhotoPath 	 Type: VARCHAR(8000)

# %% [raw]
# # Expected Output:
#
# Table Name: Employee
#
# Name: Id 	 Type: INTEGER
# Name: LastName 	 Type: VARCHAR(8000)
# Name: FirstName 	 Type: VARCHAR(8000)
# Name: Title 	 Type: VARCHAR(8000)
# Name: TitleOfCourtesy 	 Type: VARCHAR(8000)
# Name: BirthDate 	 Type: VARCHAR(8000)
# Name: HireDate 	 Type: VARCHAR(8000)
# Name: Address 	 Type: VARCHAR(8000)
# Name: City 	 Type: VARCHAR(8000)
# Name: Region 	 Type: VARCHAR(8000)
# Name: PostalCode 	 Type: VARCHAR(8000)
# Name: Country 	 Type: VARCHAR(8000)
# Name: HomePhone 	 Type: VARCHAR(8000)
# Name: Extension 	 Type: VARCHAR(8000)
# Name: Photo 	 Type: BLOB
# Name: Notes 	 Type: VARCHAR(8000)
# Name: ReportsTo 	 Type: INTEGER
# Name: PhotoPath 	 Type: VARCHAR(8000)

# %% [markdown]
# ## Connecting and Executing Raw SQL Statements
#
# Sometimes, the easiest thing for us to do is to just execute a raw SQL statement.  This is very easy with SQLAlchemy--we just need to establish a connection, and then use the appropriat methods to execute SQL statements!
#
# In the cell below:
#
# * Create a connection using the `engine` object's appropriate method and store it in the variable `con`
# * Use the appropriate method from `con` to execute a raw SQL statement (in the form of a string) that gets everything from the `'Customer'` table with a LIMIT of 5. Store the results returned in the variable `rs`
# * Use the `fetchall()` method to display all results from `rs`.

# %%
con = engine.connect()
rs = con.execute('SELECT * FROM Customer LIMIT 5')

print(rs.fetchall())
# Out:
# 2019-01-19 22:39:21,883 INFO sqlalchemy.engine.base.Engine SELECT * FROM Customer LIMIT 5
# 2019-01-19 22:39:21,884 INFO sqlalchemy.engine.base.Engine ()
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', 'Western Europe', '12209', 'Germany', '030-0074321', '030-0076545'), ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', 'Central America', '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'), ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', 'Central America', '05023', 'Mexico', '(5) 555-3932', None), ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', 'British Isles', 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', 'Northern Europe', 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67')]

# %% [raw]
# # Expected Output:
#
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', 'Western Europe', '12209', 'Germany', '030-0074321', '030-0076545'), ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constitución 2222', 'México D.F.', 'Central America', '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'), ('ANTON', 'Antonio Moreno Taquería', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'México D.F.', 'Central America', '05023', 'Mexico', '(5) 555-3932', None), ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', 'British Isles', 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BERGS', 'Berglunds snabbköp', 'Christina Berglund', 'Order Administrator', 'Berguvsvägen  8', 'Luleå', 'Northern Europe', 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67')]

# %% [markdown]
# ## Incorporating Pandas DataFrames
#
# So far we've been able to easily connect to a SQL database, inspect the tables, and execute queries. However, the results returned from queries haven't been in an easily readable format.  We'll fix that by taking the results and storing it in a pandas DataFrame!
#
# In the cell below:
#
# * Import pandas and set the standard alias.
# * Create and execute a query that gets The firstname, lastname, and title of every person in the `'Employee'` table.
# * Create a pandas DataFrame out of the results returned from `rs.fetchall()`
# * Display the head of the new DataFRame

# %%
import pandas as pd

rs = con.execute('SELECT firstname, lastname, title FROM Employee')
df = pd.DataFrame(rs.fetchall())
df.head()
# Out:
# 2019-01-19 22:41:32,127 INFO sqlalchemy.engine.base.Engine SELECT firstname, lastname, title FROM Employee
# 2019-01-19 22:41:32,128 INFO sqlalchemy.engine.base.Engine ()
#           0          1                      2
# 0     Nancy    Davolio   Sales Representative
# 1    Andrew     Fuller  Vice President, Sales
# 2     Janet  Leverling   Sales Representative
# 3  Margaret    Peacock   Sales Representative
# 4    Steven   Buchanan          Sales Manager

# %% [markdown]
# Nice! We can now read our results.  However, the columns of our DataFrame aren't labeled.  Luckily, pandas plays nicely with the sqlalchemy library, and can actually execute sql queries!

# %% [markdown]
# ### Writing Queries with Pandas
#
# In the cell below:
#
# * Use the appropriate method from pandas to select all columns for every row in the `[Order]` table where the customer is `'VINET'`
# * Be sure to pass in our `engine` as the 2nd parameter, otherwise it won't work!
# * Display the head of the DataFrame created to ensure everything worked correctly.

# %%
get_columns_info('Order')
# Out:
# 2019-01-19 22:43:56,995 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Order")
# 2019-01-19 22:43:56,996 INFO sqlalchemy.engine.base.Engine ()
# Table Name: Order
#
# Name: Id 	 Type: INTEGER
# Name: CustomerId 	 Type: VARCHAR(8000)
# Name: EmployeeId 	 Type: INTEGER
# Name: OrderDate 	 Type: VARCHAR(8000)
# Name: RequiredDate 	 Type: VARCHAR(8000)
# Name: ShippedDate 	 Type: VARCHAR(8000)
# Name: ShipVia 	 Type: INTEGER
# Name: Freight 	 Type: DECIMAL
# Name: ShipName 	 Type: VARCHAR(8000)
# Name: ShipAddress 	 Type: VARCHAR(8000)
# Name: ShipCity 	 Type: VARCHAR(8000)
# Name: ShipRegion 	 Type: VARCHAR(8000)
# Name: ShipPostalCode 	 Type: VARCHAR(8000)
# Name: ShipCountry 	 Type: VARCHAR(8000)

# %%
df = pd.read_sql_query("SELECT * FROM [Order] WHERE CustomerId='VINET'", engine)
df.head()
# Out:
# 2019-01-19 22:47:17,861 INFO sqlalchemy.engine.base.Engine SELECT * FROM [Order] WHERE CustomerId='VINET'
# 2019-01-19 22:47:17,862 INFO sqlalchemy.engine.base.Engine ()
#       Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  ShipVia  \
# 0  10248      VINET           5  2012-07-04   2012-08-01  2012-07-16        3
# 1  10274      VINET           6  2012-08-06   2012-09-03  2012-08-16        1
# 2  10295      VINET           2  2012-09-02   2012-09-30  2012-09-10        2
# 3  10737      VINET           2  2013-11-11   2013-12-09  2013-11-18        2
# 4  10739      VINET           3  2013-11-12   2013-12-10  2013-11-17        3
#
#    Freight                   ShipName         ShipAddress ShipCity  \
# 0    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 1     6.01  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 2     1.15  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 3     7.79  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
# 4    11.08  Vins et alcools Chevalier  59 rue de l'Abbaye    Reims
#
#        ShipRegion ShipPostalCode ShipCountry
# 0  Western Europe          51100      France
# 1  Western Europe          51100      France
# 2  Western Europe          51100      France
# 3  Western Europe          51100      France
# 4  Western Europe          51100      France

# %% [markdown]
# Great! As we can see from the output above, when we let pandas execute the SQL query for us, the DataFrame now contains columns with the correct labels. This is a great way to execute SQL while still making sure our results are easy to read and manipulate by using DataFrames!
#
# ## Executing JOIN Statements
#
# Let's try executing a JOIN statement inside `pd.read_sql_query`.
#
# In the cell below:
#
# * Write a query that gets the Order ID, Company Name, and the total count of orders made by each company (as num_orders).
# * Group the results by Company Name
# * Order the results by num_orders, descending
# * Display the head of the DataFrame to ensure everything worked correctly.

# %%
df = pd.read_sql_query("SELECT o.id, c.companyname, COUNT(*) num_orders FROM [Order] o INNER JOIN Customer c on o.customerid = c.id GROUP BY c.companyname ORDER BY num_orders DESC", engine)
df.head()
# Out:
# 2019-01-19 23:00:01,953 INFO sqlalchemy.engine.base.Engine SELECT o.id, c.companyname, COUNT(*) num_orders FROM [Order] o INNER JOIN Customer c on o.customerid = c.id GROUP BY c.companyname ORDER BY num_orders DESC
# 2019-01-19 23:00:01,954 INFO sqlalchemy.engine.base.Engine ()
#       Id                   CompanyName  num_orders
# 0  11064            Save-a-lot Markets          31
# 1  11072                  Ernst Handel          30
# 2  11021                    QUICK-Stop          28
# 3  11050                Folk och fä HB          19
# 4  11063  Hungry Owl All-Night Grocers          19

# %% [markdown]
# ### Expected Output
#
# <img src='join_results.png'>
#
# Great job! Let's see if we can execute a join that includes entities with a many-to-many relationship.
#
# ### JOINs with Many-To-Many Relationships
#
# In the cell below:
#
# * Write a query that selects the LastName, FirstName and number of territories assigned for every employee.
# * Group the results by employee lastname
# * Order by the total number of territories assigned to each employee, descending
# * You'll need to make use a join table to solve this one--be sure to take a look at the ERD diagram again if needed!
# * Store your results in a DataFrame and display the head to ensure that everything worked correctly.
#
# **_NOTE:_** For long SQL statements, consider using the multiline string format in python, denoted by `"""three quotes"""` at the beginning and end.  Note that if you hit enter to move to another line, be sure to add an `\` character at the end of the line to escape it--otherwise, your sql statements will contain `\n` newline characters wherever you hit enter to move to the next line.

# %%
get_columns_info('Employee'), get_columns_info('EmployeeTerritory'), get_columns_info('Territory')
# Out:
# Table Name: Employee
#
# Name: Id 	 Type: INTEGER
# Name: LastName 	 Type: VARCHAR(8000)
# Name: FirstName 	 Type: VARCHAR(8000)
# Name: Title 	 Type: VARCHAR(8000)
# Name: TitleOfCourtesy 	 Type: VARCHAR(8000)
# Name: BirthDate 	 Type: VARCHAR(8000)
# Name: HireDate 	 Type: VARCHAR(8000)
# Name: Address 	 Type: VARCHAR(8000)
# Name: City 	 Type: VARCHAR(8000)
# Name: Region 	 Type: VARCHAR(8000)
# Name: PostalCode 	 Type: VARCHAR(8000)
# Name: Country 	 Type: VARCHAR(8000)
# Name: HomePhone 	 Type: VARCHAR(8000)
# Name: Extension 	 Type: VARCHAR(8000)
# Name: Photo 	 Type: BLOB
# Name: Notes 	 Type: VARCHAR(8000)
# Name: ReportsTo 	 Type: INTEGER
# Name: PhotoPath 	 Type: VARCHAR(8000)
# 2019-01-19 23:09:06,511 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("EmployeeTerritory")
# 2019-01-19 23:09:06,512 INFO sqlalchemy.engine.base.Engine ()
# Table Name: EmployeeTerritory
#
# Name: Id 	 Type: VARCHAR(8000)
# Name: EmployeeId 	 Type: INTEGER
# Name: TerritoryId 	 Type: VARCHAR(8000)
# 2019-01-19 23:09:06,515 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Territory")
# 2019-01-19 23:09:06,516 INFO sqlalchemy.engine.base.Engine ()
# Table Name: Territory
#
# Name: Id 	 Type: VARCHAR(8000)
# Name: TerritoryDescription 	 Type: VARCHAR(8000)
# Name: RegionId 	 Type: INTEGER
# (None, None, None)

# %%
q = """SELECT e.lastname, e.firstname, COUNT(*) TerritoriesAssigned FROM employee e \
INNER JOIN employeeterritory et ON e.id = et.employeeid \
INNER JOIN territory t ON et.territoryid = t.id \
GROUP BY e.id ORDER BY TerritoriesAssigned DESC"""

df2 = pd.read_sql_query(q, engine)
df2.head()
# Out:
# 2019-01-19 23:17:37,304 INFO sqlalchemy.engine.base.Engine SELECT e.lastname, e.firstname, COUNT(*) TerritoriesAssigned FROM employee e INNER JOIN employeeterritory et ON e.id = et.employeeid INNER JOIN territory t ON et.territoryid = t.id GROUP BY e.id ORDER BY TerritoriesAssigned DESC
# 2019-01-19 23:17:37,306 INFO sqlalchemy.engine.base.Engine ()
#     LastName FirstName  TerritoriesAssigned
# 0       King    Robert                   10
# 1     Fuller    Andrew                    7
# 2   Buchanan    Steven                    7
# 3  Dodsworth      Anne                    7
# 4     Suyama   Michael                    5

# %% [markdown]
# #### Expected Output:
#
# <img src='many-to-many-results.png'>

# %% [markdown]
# Great job! You've demonstrated proficiency using raw sql with SQLAlchemy. However, we haven't yet touched all the fun declarative stuff.  Let's get some practice working with SQLAlchemy `session` objects below!
#
# ## Using SQLAlchemy Sessions
#
# So far, we've just been using SQLAlchemy as a way to connect to a database and run SQL queries. However, SQLAlchemy is an **_Object-Relational Mapper_**, and can map entities in our database to python objects! This can be incredibly helpful when we need to incorporate data from our database into an object-oriented program or model.
#
# Let's start by getting some practice with `session` objects, because that's where all the magic happens.
#
# ### Using `.query` Objects
#
# Recall that we created a `session` object at the beginning of this lab by using SQLAlchemy's `sessionmaker` function and binding it to our `engine` object.  We haven't used our `session` object too much thus far, but now we'll use it for queries!
#
# The `session` object contains a `.query()` method which returns a query object containing the results of our query, with the results mapped to objects.
#
# Before we can make use of Object-Relational Mappings, we need to make sure that we have mappings created that map the tables in our existing database to objects in python.  We don't want to have to do this manually, so we'll make use the `automap` module inside of `sqlalchemy.ext`.
#
# In the cell below:
#
# * Import `MetaData` from `sqlalchemy`
# * Import `automap_base` from `sqlalchemy.ext.automap`
# * Create a `MetaData` object
# * Use the metadata object's `reflect` method on our `engine`
# * Call `automap_base` and set the `metadata` parameter to our `metadata`. Store the results returned inside of the variable `Base`
# * Call `base.prepare()`
# * Map `Employee` and `Customer` to the `Employee` and `Customer` classes, which can be found inside of `Base.classes`

# %%
from sqlalchemy import MetaData
from sqlalchemy.ext.automap import automap_base

metadata = MetaData()

metadata.reflect(engine)

Base = automap_base(metadata=metadata)
Base.prepare()

# Don't forget to .prepare()!

Employee, Customer = Base.classes.Employee, Base.classes.Customer
# Out:
# 2019-01-19 23:21:22,497 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2019-01-19 23:21:22,498 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,501 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Category")
# 2019-01-19 23:21:22,501 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,503 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-01-19 23:21:22,504 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,505 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Category")
# 2019-01-19 23:21:22,506 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,507 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-01-19 23:21:22,508 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,511 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Category")
# 2019-01-19 23:21:22,512 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,513 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Category")
# 2019-01-19 23:21:22,513 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,514 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Category' AND type = 'table'
# 2019-01-19 23:21:22,515 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,518 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Customer")
# 2019-01-19 23:21:22,518 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,523 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-01-19 23:21:22,523 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,524 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Customer")
# 2019-01-19 23:21:22,525 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,526 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-01-19 23:21:22,527 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,528 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Customer")
# 2019-01-19 23:21:22,529 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,530 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Customer")
# 2019-01-19 23:21:22,531 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,532 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_Customer_1")
# 2019-01-19 23:21:22,532 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,533 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Customer' AND type = 'table'
# 2019-01-19 23:21:22,534 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,536 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("CustomerCustomerDemo")
# 2019-01-19 23:21:22,536 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,537 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-01-19 23:21:22,538 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,539 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("CustomerCustomerDemo")
# 2019-01-19 23:21:22,540 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,541 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-01-19 23:21:22,541 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,542 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerCustomerDemo")
# 2019-01-19 23:21:22,543 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,544 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerCustomerDemo")
# 2019-01-19 23:21:22,545 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,546 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_CustomerCustomerDemo_1")
# 2019-01-19 23:21:22,546 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,547 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerCustomerDemo' AND type = 'table'
# 2019-01-19 23:21:22,548 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,549 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("CustomerDemographic")
# 2019-01-19 23:21:22,550 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,551 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-01-19 23:21:22,552 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,553 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("CustomerDemographic")
# 2019-01-19 23:21:22,554 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,555 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-01-19 23:21:22,556 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,556 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerDemographic")
# 2019-01-19 23:21:22,557 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,558 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("CustomerDemographic")
# 2019-01-19 23:21:22,559 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,560 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_CustomerDemographic_1")
# 2019-01-19 23:21:22,561 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,562 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'CustomerDemographic' AND type = 'table'
# 2019-01-19 23:21:22,562 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,564 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Employee")
# 2019-01-19 23:21:22,565 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,572 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-01-19 23:21:22,594 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,595 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Employee")
# 2019-01-19 23:21:22,596 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,597 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-01-19 23:21:22,602 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,604 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Employee")
# 2019-01-19 23:21:22,607 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,609 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Employee")
# 2019-01-19 23:21:22,610 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,611 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Employee' AND type = 'table'
# 2019-01-19 23:21:22,612 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,613 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("EmployeeTerritory")
# 2019-01-19 23:21:22,614 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,616 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-01-19 23:21:22,617 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,619 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("EmployeeTerritory")
# 2019-01-19 23:21:22,620 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,621 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-01-19 23:21:22,622 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,624 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("EmployeeTerritory")
# 2019-01-19 23:21:22,626 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,627 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("EmployeeTerritory")
# 2019-01-19 23:21:22,627 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,629 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_EmployeeTerritory_1")
# 2019-01-19 23:21:22,629 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,630 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'EmployeeTerritory' AND type = 'table'
# 2019-01-19 23:21:22,631 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,632 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Order")
# 2019-01-19 23:21:22,633 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,637 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-01-19 23:21:22,638 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,640 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Order")
# 2019-01-19 23:21:22,640 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,641 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-01-19 23:21:22,641 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,643 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Order")
# 2019-01-19 23:21:22,644 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,645 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Order")
# 2019-01-19 23:21:22,645 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,646 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Order' AND type = 'table'
# 2019-01-19 23:21:22,647 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,648 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("OrderDetail")
# 2019-01-19 23:21:22,649 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,650 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-01-19 23:21:22,651 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,652 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("OrderDetail")
# 2019-01-19 23:21:22,653 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,654 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-01-19 23:21:22,654 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,655 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("OrderDetail")
# 2019-01-19 23:21:22,656 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,657 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("OrderDetail")
# 2019-01-19 23:21:22,658 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,659 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_OrderDetail_1")
# 2019-01-19 23:21:22,660 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,660 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'OrderDetail' AND type = 'table'
# 2019-01-19 23:21:22,661 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,663 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Product")
# 2019-01-19 23:21:22,663 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,666 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-01-19 23:21:22,667 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,668 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Product")
# 2019-01-19 23:21:22,669 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,670 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-01-19 23:21:22,670 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,671 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Product")
# 2019-01-19 23:21:22,672 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,673 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Product")
# 2019-01-19 23:21:22,673 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,674 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Product' AND type = 'table'
# 2019-01-19 23:21:22,675 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,676 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Region")
# 2019-01-19 23:21:22,677 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,679 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-01-19 23:21:22,680 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,686 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Region")
# 2019-01-19 23:21:22,689 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,700 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-01-19 23:21:22,701 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,703 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Region")
# 2019-01-19 23:21:22,704 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,706 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Region")
# 2019-01-19 23:21:22,707 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,708 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Region' AND type = 'table'
# 2019-01-19 23:21:22,709 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,710 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Shipper")
# 2019-01-19 23:21:22,711 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,713 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-01-19 23:21:22,714 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,715 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Shipper")
# 2019-01-19 23:21:22,716 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,717 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-01-19 23:21:22,717 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,718 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Shipper")
# 2019-01-19 23:21:22,719 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,720 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Shipper")
# 2019-01-19 23:21:22,720 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,721 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Shipper' AND type = 'table'
# 2019-01-19 23:21:22,722 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,723 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Supplier")
# 2019-01-19 23:21:22,724 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,725 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-01-19 23:21:22,726 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,728 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Supplier")
# 2019-01-19 23:21:22,729 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,729 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-01-19 23:21:22,730 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,731 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Supplier")
# 2019-01-19 23:21:22,732 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,733 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Supplier")
# 2019-01-19 23:21:22,733 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,734 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Supplier' AND type = 'table'
# 2019-01-19 23:21:22,735 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,737 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Territory")
# 2019-01-19 23:21:22,737 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,750 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-01-19 23:21:22,753 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,756 INFO sqlalchemy.engine.base.Engine PRAGMA foreign_key_list("Territory")
# 2019-01-19 23:21:22,756 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,757 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-01-19 23:21:22,758 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,759 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Territory")
# 2019-01-19 23:21:22,760 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,762 INFO sqlalchemy.engine.base.Engine PRAGMA index_list("Territory")
# 2019-01-19 23:21:22,763 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,764 INFO sqlalchemy.engine.base.Engine PRAGMA index_info("sqlite_autoindex_Territory_1")
# 2019-01-19 23:21:22,764 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-19 23:21:22,766 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = 'Territory' AND type = 'table'
# 2019-01-19 23:21:22,767 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# Now that we have some mappings set up, we can make use of `session.query()` help us query our database!
#
# ### Writing Basic Queries
#
# Let's use the `query()` object to get all the employees from the `'Employee'` table.
#
# In the cell below:
#
# * Create a for loop that iterates through the results returned by a `session.query()` of the Employee table (pass this as a variable, not a string).
# * Order the results by the Employee's `.HireDate` attribute.
# * Print the last name, first name, and hire date of each employee.

# %%
for instance in session.query(Employee).order_by(Employee.HireDate):
    print(instance.LastName, instance.FirstName, instance.HireDate)
# Out:
# 2019-01-19 23:24:29,896 INFO sqlalchemy.engine.base.Engine SELECT "Employee"."Id" AS "Employee_Id", "Employee"."LastName" AS "Employee_LastName", "Employee"."FirstName" AS "Employee_FirstName", "Employee"."Title" AS "Employee_Title", "Employee"."TitleOfCourtesy" AS "Employee_TitleOfCourtesy", "Employee"."BirthDate" AS "Employee_BirthDate", "Employee"."HireDate" AS "Employee_HireDate", "Employee"."Address" AS "Employee_Address", "Employee"."City" AS "Employee_City", "Employee"."Region" AS "Employee_Region", "Employee"."PostalCode" AS "Employee_PostalCode", "Employee"."Country" AS "Employee_Country", "Employee"."HomePhone" AS "Employee_HomePhone", "Employee"."Extension" AS "Employee_Extension", "Employee"."Photo" AS "Employee_Photo", "Employee"."Notes" AS "Employee_Notes", "Employee"."ReportsTo" AS "Employee_ReportsTo", "Employee"."PhotoPath" AS "Employee_PhotoPath"
# FROM "Employee" ORDER BY "Employee"."HireDate"
# 2019-01-19 23:24:29,897 INFO sqlalchemy.engine.base.Engine ()
# Leverling Janet 2024-04-01
# Davolio Nancy 2024-05-01
# Fuller Andrew 2024-08-14
# Peacock Margaret 2025-05-03
# Buchanan Steven 2025-10-17
# Suyama Michael 2025-10-17
# King Robert 2026-01-02
# Callahan Laura 2026-03-05
# Dodsworth Anne 2026-11-15

# %% [markdown]
# ### Implicit JOINs using `.filter()`
#
# One great benefit of using `session.query()` to query our data is that we can easily execute **_implicit joins_** by making use of the `.filter()` method.
#
# So far we've only explicitly specified mappings for the `Employee` and `Customer` classes.  We'll need to do this now for the `Product` and `Category` classes before we can use them with `session.query()`.
#
# In the cell below, set the mappings for `Product` and `Category`.
#
# **_HINT:_** This will look just like the last line of the code cell where we declared our mappings previously.  No need to repeat all the steps for getting metadata and creating a `Base` class. Just set the mappings!

# %%
Product, Category = Base.classes.Product, Base.classes.Category

# %% [markdown]
# Great!
#
# Now, in the cell below:
#
# * Create a for loop that iterates through all results returned from a query of Products and Categories
# * Use the `.filter()` method to only include cases where the Product's `.CategoryID` matches the Category's `.Id` attribute.
# * Print out the name of each product, followed by the name of the category that it belongs to.

# %%
get_columns_info("Product"), get_columns_info('Category')
# Out:
# 2019-01-19 23:28:04,506 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Product")
# 2019-01-19 23:28:04,507 INFO sqlalchemy.engine.base.Engine ()
# Table Name: Product
#
# Name: Id 	 Type: INTEGER
# Name: ProductName 	 Type: VARCHAR(8000)
# Name: SupplierId 	 Type: INTEGER
# Name: CategoryId 	 Type: INTEGER
# Name: QuantityPerUnit 	 Type: VARCHAR(8000)
# Name: UnitPrice 	 Type: DECIMAL
# Name: UnitsInStock 	 Type: INTEGER
# Name: UnitsOnOrder 	 Type: INTEGER
# Name: ReorderLevel 	 Type: INTEGER
# Name: Discontinued 	 Type: INTEGER
# 2019-01-19 23:28:04,511 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("Category")
# 2019-01-19 23:28:04,511 INFO sqlalchemy.engine.base.Engine ()
# Table Name: Category
#
# Name: Id 	 Type: INTEGER
# Name: CategoryName 	 Type: VARCHAR(8000)
# Name: Description 	 Type: VARCHAR(8000)
# (None, None)

# %%
for P, C in session.query(Product, Category).filter(Product.CategoryId == Category.Id).all():
    print("Product:", P.ProductName, "\nCategory:", C.CategoryName, "\n")
# Out:
# 2019-01-19 23:31:47,005 INFO sqlalchemy.engine.base.Engine SELECT "Product"."Id" AS "Product_Id", "Product"."ProductName" AS "Product_ProductName", "Product"."SupplierId" AS "Product_SupplierId", "Product"."CategoryId" AS "Product_CategoryId", "Product"."QuantityPerUnit" AS "Product_QuantityPerUnit", "Product"."UnitPrice" AS "Product_UnitPrice", "Product"."UnitsInStock" AS "Product_UnitsInStock", "Product"."UnitsOnOrder" AS "Product_UnitsOnOrder", "Product"."ReorderLevel" AS "Product_ReorderLevel", "Product"."Discontinued" AS "Product_Discontinued", "Category"."Id" AS "Category_Id", "Category"."CategoryName" AS "Category_CategoryName", "Category"."Description" AS "Category_Description"
# FROM "Product", "Category"
# WHERE "Product"."CategoryId" = "Category"."Id"
# 2019-01-19 23:31:47,006 INFO sqlalchemy.engine.base.Engine ()
# Product: Chai
# Category: Beverages
#
# Product: Chang
# Category: Beverages
#
# Product: Aniseed Syrup
# Category: Condiments
#
# Product: Chef Anton's Cajun Seasoning
# Category: Condiments
#
# Product: Chef Anton's Gumbo Mix
# Category: Condiments
#
# Product: Grandma's Boysenberry Spread
# Category: Condiments
#
# Product: Uncle Bob's Organic Dried Pears
# Category: Produce
#
# Product: Northwoods Cranberry Sauce
# Category: Condiments
#
# Product: Mishi Kobe Niku
# Category: Meat/Poultry
#
# Product: Ikura
# Category: Seafood
#
# Product: Queso Cabrales
# Category: Dairy Products
#
# Product: Queso Manchego La Pastora
# Category: Dairy Products
#
# Product: Konbu
# Category: Seafood
#
# Product: Tofu
# Category: Produce
#
# Product: Genen Shouyu
# Category: Condiments
#
# Product: Pavlova
# Category: Confections
#
# Product: Alice Mutton
# Category: Meat/Poultry
#
# Product: Carnarvon Tigers
# Category: Seafood
#
# Product: Teatime Chocolate Biscuits
# Category: Confections
#
# Product: Sir Rodney's Marmalade
# Category: Confections
#
# Product: Sir Rodney's Scones
# Category: Confections
#
# Product: Gustaf's Knäckebröd
# Category: Grains/Cereals
#
# Product: Tunnbröd
# Category: Grains/Cereals
#
# Product: Guaraná Fantástica
# Category: Beverages
#
# Product: NuNuCa Nuß-Nougat-Creme
# Category: Confections
#
# Product: Gumbär Gummibärchen
# Category: Confections
#
# Product: Schoggi Schokolade
# Category: Confections
#
# Product: Rössle Sauerkraut
# Category: Produce
#
# Product: Thüringer Rostbratwurst
# Category: Meat/Poultry
#
# Product: Nord-Ost Matjeshering
# Category: Seafood
#
# Product: Gorgonzola Telino
# Category: Dairy Products
#
# Product: Mascarpone Fabioli
# Category: Dairy Products
#
# Product: Geitost
# Category: Dairy Products
#
# Product: Sasquatch Ale
# Category: Beverages
#
# Product: Steeleye Stout
# Category: Beverages
#
# Product: Inlagd Sill
# Category: Seafood
#
# Product: Gravad lax
# Category: Seafood
#
# Product: Côte de Blaye
# Category: Beverages
#
# Product: Chartreuse verte
# Category: Beverages
#
# Product: Boston Crab Meat
# Category: Seafood
#
# Product: Jack's New England Clam Chowder
# Category: Seafood
#
# Product: Singaporean Hokkien Fried Mee
# Category: Grains/Cereals
#
# Product: Ipoh Coffee
# Category: Beverages
#
# Product: Gula Malacca
# Category: Condiments
#
# Product: Rogede sild
# Category: Seafood
#
# Product: Spegesild
# Category: Seafood
#
# Product: Zaanse koeken
# Category: Confections
#
# Product: Chocolade
# Category: Confections
#
# Product: Maxilaku
# Category: Confections
#
# Product: Valkoinen suklaa
# Category: Confections
#
# Product: Manjimup Dried Apples
# Category: Produce
#
# Product: Filo Mix
# Category: Grains/Cereals
#
# Product: Perth Pasties
# Category: Meat/Poultry
#
# Product: Tourtière
# Category: Meat/Poultry
#
# Product: Pâté chinois
# Category: Meat/Poultry
#
# Product: Gnocchi di nonna Alice
# Category: Grains/Cereals
#
# Product: Ravioli Angelo
# Category: Grains/Cereals
#
# Product: Escargots de Bourgogne
# Category: Seafood
#
# Product: Raclette Courdavault
# Category: Dairy Products
#
# Product: Camembert Pierrot
# Category: Dairy Products
#
# Product: Sirop d'érable
# Category: Condiments
#
# Product: Tarte au sucre
# Category: Confections
#
# Product: Vegie-spread
# Category: Condiments
#
# Product: Wimmers gute Semmelknödel
# Category: Grains/Cereals
#
# Product: Louisiana Fiery Hot Pepper Sauce
# Category: Condiments
#
# Product: Louisiana Hot Spiced Okra
# Category: Condiments
#
# Product: Laughing Lumberjack Lager
# Category: Beverages
#
# Product: Scottish Longbreads
# Category: Confections
#
# Product: Gudbrandsdalsost
# Category: Dairy Products
#
# Product: Outback Lager
# Category: Beverages
#
# Product: Flotemysost
# Category: Dairy Products
#
# Product: Mozzarella di Giovanni
# Category: Dairy Products
#
# Product: Röd Kaviar
# Category: Seafood
#
# Product: Longlife Tofu
# Category: Produce
#
# Product: Rhönbräu Klosterbier
# Category: Beverages
#
# Product: Lakkalikööri
# Category: Beverages
#
# Product: Original Frankfurter grüne Soße
# Category: Condiments

# %% [markdown]
# ## Summary
#
# Great job! You've just used SQLAlchemy to work with a sample production database. Note that there are many, many more awesome things that SQLAlchemy can do, but they're outside the scope of this lesson.  However, if you're interested in learning more, don't be afraid to take a look at the [SQLAlchemy documentation](https://docs.sqlalchemy.org/en/latest/orm/tutorial.html) and work through some tutorials in your spare time!
